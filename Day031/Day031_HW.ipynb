# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
r = requests.get("https://shopee.tw/shop/3625341/search/")
r.text
# Out:
# '<!DOCTYPE html>\n<html>\n  <head>\n    \n    <link\n      rel="preconnect"\n      href="//cf.shopee.tw/"\n    />\n    \n    <link\n      rel="preconnect"\n      href="//deo.shopeemobile.com/shopee/"\n    />\n    \n    <link\n      rel="preconnect"\n      href="//cv.shopee.tw/"\n    />\n    \n\n    <meta charset="utf-8" />\n    <meta\n      name="viewport"\n      content="width=device-width, initial-scale=1, maximum-scale=1, minimum-scale=1, user-scalable=no, viewport-fit=cover"\n    />\n    <meta name="shopee:git-sha" content="a40b4623fd9e89c81016202065531caa78a784ab">\n    <meta name="shopee:version" content="rw-v3.52.0">\n\n    <script>\n      window.__PAGE_ID__ = 12;\n      window.__LOCALE__ = \'TW\';\n      window.__ENV__ = \'live\';\n      window.__ASSETS__ = {"CCMS_FEATURE_TOGGLE":{"ALL_CATEGORIES_HOMEPAGE_ENTRANCE":{"default":false,"TW":true,"VN":true,"PH":true,"MY":true,"ID":true},"AMP_CATEGORY_PAGE":{"default":true},"BUNDLE_DEALS":{"default":true},"BUNDLE_DEAL_11":{"default
# ...

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "accept-encoding": "gzip, deflate, br",
    "accept-language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    "cache-control": "max-age=0",
    "cookie": "_fbp=fb.1.1587704773514.621353476; SPC_IA=-1; SPC_EC=-; SPC_U=-; SPC_F=cnjHel4NAHit0NMcMILSdzIcjqSuzCUx; REC_T_ID=529c8d32-85e9-11ea-8a0d-f8f21e1ae922; _ga=GA1.2.732967713.1587704775; __BWfp=c1587704775618xb426c1d01; _med=refer; _gcl_au=1.1.1476463853.1597309802; SPC_CT_934a8fe6='1597309806.tkFy3RyOygMiJjtT+HP6VD8jze/zki+z9jz261Ak+Mg='; SPC_SI=t4rwn9xlyldm226d5gweucbd4m84fasa; AMP_TOKEN=%24NOT_FOUND; _gid=GA1.2.573351291.1597309806; _dc_gtm_UA-61915057-6=1; SPC_CT_f456a831='1597309884.MKKWfJ7lO669LSYtTZH5v3Qoosvzf7aCI+opIDE26UY='; SPC_CT_9cc19f4b='1597309884.9kIVKddiEiO4JE+NyiaooHCpqOMBdkiYjEKaGJSI2Xo='; SPC_CT_8ebfdfee='1597309885.Rm12YTsMkWwW0zQur97rj2yOycp/2KFcmMZtTly+43U='; SPC_R_T_ID='1piIQM8stD+D/fzsm7WFO500f7tzEcfcKPjseTNQUGHf4l83rMu9ws+13Vpn62g/bTCs4F+n9Ig9qwXu5zoSLlBlzkdyi7S5Ze7ap3KT5Q4='; SPC_T_IV='iAdBiIQd+JjlRQSJZv0oxA=='; SPC_R_T_IV='iAdBiIQd+JjlRQSJZv0oxA=='; SPC_T_ID='1piIQM8stD+D/fzsm7WFO500f7tzEcfcKPjseTNQUGHf4l83rMu9ws+13Vpn62g/bTCs4F+n9Ig9qwXu5zoSLlBlzkdyi7S5Ze7ap3KT5Q4='",
    "referer": "https://ithelp.ithome.com.tw/questions/10189512",
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "cross-site",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.125 Safari/537.36}"
}
r1 = requests.get("https://shopee.tw/shop/3625341/search/", headers=headers)
r1.text
# Out:
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="viewport"\n    content="width=device-width, initial-scale=1, maximum-scale=1, minimum-scale=1, user-scalable=no">\n  <meta name="shopee:git-sha" content="0fd515b1f3b8a5716b0d8c818eb2916685cec980">\n  <meta name="shopee:version" content="pc-v4.51.0">\n  <script data-webfe="config">\n    window.__PAGE_ID__ = 1;\n    window.__LOCALE__ = \'TW\';\n    window.__ENV__ = \'live\';\n    window.__ASSETS__ = {"CCMS_FEATURE_TOGGLE":{"ADDON_DEAL":{"default":true,"MY":false,"TH":false},"ADDRESS_GEOLOCATION_SELECTOR":{"TH":true,"default":false,"VN":true,"BR":true,"IN":true,"PH":true,"MY":true,"ID":true},"ADDRESS_SELECT_ZIPCODE":{"default":false,"ID":true,"TH":true},"AMEX_CC":{"default":false,"TW":false,"VN":true,"IN":true,"SG":true,"ID":true},"BRAND_LIST":{"default":true,"BR":false,"IN":false},"BUNDLE_DEAL_USE_11":{"default":true},"DAILY_DISCOVER_TABS":{"default":false,"MY":true,"ID":true,"BR":true},"DEFAULT_RATING_FIVE":{"
# ...

# %%
r.text == r1.text
# Out:
# False
