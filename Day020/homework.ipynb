# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。

# %% [markdown]
# * 請附上截圖：_______
#
# ![api.png](attachment:api.png)

# %%
import requests
r = requests.get("https://www.dcard.tw/service/api/v2/posts?popular=true&limit=30&before=234171619")
r.json()
# Out:
# [{'id': 234172721,
#   'title': '為什麼搞gay是種笑話？',
#   'excerpt': '最近網路很紅的哆啦av夢，描述胖虎和小夫偷情被發現，試問，如果主角改成靜香和小杉，大家會笑成這樣嗎？頂多就是普通a漫吧，很明顯，除了劇情外，大家覺得好笑很大部份原因，是因為男男搞gay！基情！，但我不',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': 'b5b2653a-6304-4564-9ea0-a4cec0be7aee',
#   'replyId': None,
#   'createdAt': '2020-08-05T05:47:54.450Z',
#   'updatedAt': '2020-08-05T16:21:01.850Z',
#   'commentCount': 269,
#   'likeCount': 492,
#   'withNickname': False,
#   'tags': [],
#   'topics': [],
#   'meta': {'layout': 'classic'},
#   'globalPinned': None,
#   'forumName': '彩虹',
#   'forumAlias': 'rainbow',
#   'nsfw': False,
#   'gender': 'M',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '423cf0f9-9cf3-4acb-aeab-e786c7fa7adf',
#     'url': 'https://i.imgur.com/I9SwcNrl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/I9SwcNrl.jpg',
#     'thumbnail': 'https://i.imgur.com/I9SwcNrl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
# ...
